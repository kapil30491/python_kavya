# %%
#TUPLE

#why Tuple
#Tuple is order collection
#Tuple cannot be changed
#faster+safer when data should not be change

#eg: Days of week
     months
     fixed coordinates

# small bracket (),  which also optional while creating a tuple

# %%
a=(10,20,30,40)
print(a, type(a))
# Out:
# (10, 20, 30, 40) <class 'tuple'>

# %%
a=10,20,30,40
print(a,type(a))
# Out:
# (10, 20, 30, 40) <class 'tuple'>

# %%
# Tuple Creation

#tpl=(10,10.20,10+20j,True,None,'Python',[1,2,3],(1,2,3),{1,2,3},{1:100,2:200,3:300})
#print(tpl,type(tpl))

#using tuple(iterable) function
#tpl1=tuple('python')
#print(tpl1,type(tpl1))

#tpl2=tuple([10,20,30,40])
#print(tpl2,type(tpl2))

#tpl3=tuple({10,20,30,40})
#print(tpl3,type(tpl3))

#tpl4=tuple({1:100,2:200,3:300})
#print(tpl4,type(tpl4))

#taking a input from the user
#tpl1=eval(input("Enter the tuple:"))
#print(tpl1,type(tpl1))

#tpl=tuple(i for i in range(4))
#print(tpl)

#create using single element
#a=10,
#print(a,type(a))
# Out:
# (0, 1, 2, 3)

# %%
# Tuple Properties

# Tuple is immutalbe
 # item assignment is not possible in tuple
 # changes will not be in the existing object

#tpl=(10,20,30,40)
#tpl[0]=111
#print(tpl)

tpl=10,20,30,40
print("before Operatin")
print(tpl,id(tpl))
print()
tpl1=tpl+(90,)
print("after Operatin")
print(tpl1,id(tpl1))
# Out:
# before Operatin
# (10, 20, 30, 40) 2257635139296
#
# after Operatin
# (10, 20, 30, 40, 90) 2257634917520

# %%
# Tuple 
#2.tuple is sequence datatype
# Tuple is order collection of elements
# tuple supoorts +ve and -ve indexing
# +ve index start 0 from LHS
# -ve index start -1 from RHS
# basic operation indexing, slicing, concatenation, repitation, membership operator


tpl=(10,10.20,10+20j,True,None,'Python',[1,2,3],(1,2,3),{1,2,3},{1:100,2:200,3:300})
# Indexing of tuple
#print(tpl[0])
#print(tpl[-len(tpl)])
#print(tpl[-1])

#slicing of tuple
#print(tpl[::])
#print(tpl[::-1])
#print(tpl[::2])

# concatenation
tpl1=(10,20,30,40)
tpl2=(50,60,70,80)
print(tpl1+tpl2)

# Repitation
tpl1=(10,20,30,40)
print(tpl1*3)
# Out:
# (10, 20, 30, 40, 50, 60, 70, 80)
# (10, 20, 30, 40, 10, 20, 30, 40, 10, 20, 30, 40)

# %%
tpl=(10,10.20,10+20j,False,None,'Python',[1,2,3],(1,2,3),{1,2,3},{1:100,2:200,3:300})
print(10 in tpl)
print(1 in tpl)
# Out:
# True
# False

# %%
# Tuple is collection of heterogenious data types

tpl=(10,10.20,10+20j,False,None,'Python',[1,2,3],(1,2,3),{1,2,3},{1:100,2:200,3:300})
print(type(tpl[0]))
print(type(tpl[1]))
print(type(tpl[2]))
print(type(tpl[3]))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'bool'>

# %%
# tuple can have duplicates elements
tpl=(10,20,30,40,10,10,10)
print(tpl)
# Out:
# (10, 20, 30, 40, 10, 10, 10)

# %%
# Tuple Methods
print(dir(tpl))

['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__dir__', 
 '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', 
 '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', 
 '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', 
 '__reduce_ex__', '__repr__', '__rmul__', '__setattr__', 
 '__sizeof__', '__str__', '__subclasshook__', 'count', 'index']
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'count', 'index']

# %%
# 'count', 'index'

# %%
#count
tpl=(10,20,30,40,10,20,30,40,10,50,30)
#tuple_name.count(10)
print(tpl.count(10))
# Out:
# 3

# %%
#index
tpl=(10,20,30,40,10,20,30,40,10,50,30)
#tpl_name.index(value))
#Return first index of value.
print(tpl.index(10))
print(tpl.index(10,1,10))
# Out:
# 0
# 4

# %%
# Tuple Packing and unpacking
#tuple Packing:  packing means putting multiple values into one tuple
#tuple unpacking: unpacking means taking a values out of a tuple into seprate variable


#emp_name='Krishna'
#emp_company='Kavya'
#emp_id='KIPL001'
#emp_pin=2345
#emp_married=True

#emp_info=emp_name,emp_company,emp_id,emp_pin,emp_married
#print(emp_info,type(emp_info))

student_info=('Aniket', 14, 'IX',87)
#tuple unpacking-- no of variable and no of elements inside the tuple should match
student_name,student_age,st_class,std_marks=student_info
print(student_name)
print(student_age)
print(st_class)
print(std_marks)
# Out:
# Aniket
# 14
# IX
# 87
