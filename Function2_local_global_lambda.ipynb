# %%
# Namespace 
# scope
# golbal and local
#Annonymous function lambda

# %%
def func_add():
    a=10
    b=20
    c=a+b
    print(c)

print(func_add())
# Out:
# 30
# None

# %%
def func_add():
    a=10
    b=20
    c=a+b
    print(c)

print(func_add)
# Out:
# <function func_add at 0x00000247073A8860>

# %%
x=100
y=100

print(id(x))
print(id(y))
# Out:
# 140722113921032
# 140722113921032

# %%
x=1000
y=x
print(id(x))
print(id(y))
# Out:
# 2504100474832
# 2504100474832

# %%
x=100
y=200

def func_add():
    a=10
    b=20
    c=a+b
    print(c)

my_func=func_add
print(my_func)
print(func_add)

my_func()
# Out:
# <function func_add at 0x000002470805A700>
# <function func_add at 0x000002470805A700>
# 30

# %%
# Namespace and scope

# Namespaces -- built in, global, local
# scope (Rule for name resulotion) -->local -->global --->built in --->Nameerror

# %%
# Built in namespace
print(dir(__builtins__))
# Out:
# ['ArithmeticError', 'AssertionError', 'AttributeError', 'BaseException', 'BaseExceptionGroup', 'BlockingIOError', 'BrokenPipeError', 'BufferError', 'BytesWarning', 'ChildProcessError', 'ConnectionAbortedError', 'ConnectionError', 'ConnectionRefusedError', 'ConnectionResetError', 'DeprecationWarning', 'EOFError', 'Ellipsis', 'EncodingWarning', 'EnvironmentError', 'Exception', 'ExceptionGroup', 'False', 'FileExistsError', 'FileNotFoundError', 'FloatingPointError', 'FutureWarning', 'GeneratorExit', 'IOError', 'ImportError', 'ImportWarning', 'IndentationError', 'IndexError', 'InterruptedError', 'IsADirectoryError', 'KeyError', 'KeyboardInterrupt', 'LookupError', 'MemoryError', 'ModuleNotFoundError', 'NameError', 'None', 'NotADirectoryError', 'NotImplemented', 'NotImplementedError', 'OSError', 'OverflowError', 'PendingDeprecationWarning', 'PermissionError', 'ProcessLookupError', 'PythonFinalizationError', 'RecursionError', 'ReferenceError', 'ResourceWarning', 'RuntimeError', 'RuntimeWarni
# ...

# %%
# Global namespaces  --> any code wrtitten outside the function defination
print(dir())
# Out:
# ['In', 'Out', '_', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__session__', '__spec__', '_dh', '_i', '_i1', '_i10', '_i11', '_i12', '_i13', '_i14', '_i15', '_i16', '_i17', '_i2', '_i3', '_i4', '_i5', '_i6', '_i7', '_i8', '_i9', '_ih', '_ii', '_iii', '_oh', 'exit', 'func_add', 'get_ipython', 'my_func', 'open', 'quit', 'x', 'y']

# %%
# local namespace
# any code written inside the function defination is local

def func_add():
    a=10
    b=20
    c=a+b
    print(c)
    print(dir())

func_add()
# Out:
# 30
# ['a', 'b', 'c']

# %%
x=100
y=100
z=x+y

def f1():
    a=10
    x=20
    b=a+x
    print(b)
    print(y)
    def f2():
        m=90
        n=89
        b=m+n
        print(b)
        print(x)
    f2()
print(x)
print(y)
#print(a)
f1()
#print(a)
print(x)
# Out:
# 100
# 100
# 30
# 100
# 179
# 20
# 100

# %%
global x=100 y=100 z=200
local a=10 x=20 b=30, y=100
     m=90 n=89, b=179, x=20

x=100

# %%
# Annoymous function
# lambda function are called the annoymous function
# The exprr result is result of value lambda function
# no need to write the written statement explicitly
# syntx
#lambda par1, par2, par3,....: expr

# define lambda function which gives square of number
#a=(lambda value: value**2)(4)
#rint(a)

a=(lambda value: value**2)
print(a(8))
a(8)
# Out:
# 64
# 64

# %%
email='swapnil.jaiswal@kavya.com'
# write a code to extract domain using lamba function

extract_domain=(lambda e:e.split('@')[1].split('.')[0])
print(extract_domain(email))
# Out:
# kavya

# %%
a='Hi my name is python'
a.split(' ')[1]
# Out:
# 'my'
